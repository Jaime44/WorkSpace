# %%
#Importamos las librerias necesarias
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import Modulo_SVM

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
#Cargamos el data set
data = pd.read_csv('C:/Users/jaime/OneDrive - Universidad de Málaga/Escritorio/Jaime/TFG/HuGaDB-master/HuGaDB_v2_Digest/DataFrameFinal.csv')

#Elimino las filas con algún valor de columna vacio 
data = data.dropna()

# %%
# Hyperparametros
nTest = 0.2
nSamples = 75000
nTrain = 1-nTest
nSamples =  round(nSamples / nTrain)
num_splits = 10
# kernels = ['poly','rbf','sigmoid', 'linear']
kernels = ['poly','rbf']

# %%
df = data
df = df[:nSamples]

# %%
# df = df[(df.act == 1) | (df.act == 2) | (df.act == 3) | (df.act == 4) | (df.act == 5) | (df.act == 6) | (df.act == 7) 
#         | (df.act == 8) | (df.act == 9) | (df.act == 12)]

# %%
X = df.drop(['act'], axis = 'columns')
y = df.act

# %%
x_values = ['Walking', 'Running', 'Going up', 'Going down', 'Sitting', 'Sitting down', 'Standing up', 'Standing', 
               'Bicycling', 'Up by elevator',  'Down by elevator',  'Sitting in car']
# x_values = ['Walking', 'Running', 'Going up', 'Going down', 'Sitting', 'Sitting down', 'Standing up', 'Standing', 
#             'Up by elevator',  'Down by elevator']
y_values = []
y_values.append((df[(df.act == 1)]).shape[0])
y_values.append((df[(df.act == 2)]).shape[0])
y_values.append((df[(df.act == 3)]).shape[0])
y_values.append((df[(df.act == 4)]).shape[0])
y_values.append((df[(df.act == 5)]).shape[0])
y_values.append((df[(df.act == 6)]).shape[0])
y_values.append((df[(df.act == 7)]).shape[0])
y_values.append((df[(df.act == 8)]).shape[0])
y_values.append((df[(df.act == 9)]).shape[0])
y_values.append((df[(df.act == 10)]).shape[0])
y_values.append((df[(df.act == 11)]).shape[0])
y_values.append((df[(df.act == 12)]).shape[0])
print(f'num of samples: {sum(y_values)}')
print(y_values)
plt.figure(figsize=(20,10))
plt.bar(x_values, y_values, width=0.8)
# Out:
# num of samples: 75000
# [20748, 4345, 8870, 7723, 5538, 1247, 1355, 14702, 0, 5919, 4553, 0]
# <BarContainer object of 12 artists>

# %%
# Modelo que entrenaremos 
# model = SVC(C=0.5,kernel = 'poly', degree=3, gamma='scale', coef0= 4, decision_function_shape='ovo'
#             ,shrinking=True, probability=True, verbose = True, random_state=42)
# model = SVC(kernel = 'poly', decision_function_shape='ovo')

# %%
#Metodo para graficar tiempos vs muestras de kernel poly 
list_samples_poly = [0,1]
list_times_poly = [0,0]
for sampl in range(6250, nSamples+1, 6250):
    show_samples = int(sampl * (1-nTest))
    print('\033[5;34m'+'Número de muestras:', show_samples, '// kernel: poly','\033[0;m')   
    
    df = data
    df = df[:sampl]
        
    X = df.drop(['act'], axis = 'columns')
    y = df.act
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=nTest, random_state=42)
        
    list_acc, time, best_model = Modulo_SVM.modl(SVC(kernel = 'poly', decision_function_shape='ovo'), X_train, y_train, 10)
        
    mean_acc = np.mean(list_acc)
    list_samples_poly.append(show_samples)
    list_times_poly.append(time)
    
   # print(f'Lista de muestras {list_samples_poly} y lista de tiempos {list_samples_poly}')
        
    print('\033[5;32m'+'Accuracy medio --> ', mean_acc, '\n'+'\033[0;m')
# Out:
# Número de muestras: 5000 // kernel: poly
# Accuracy test en split 1 --> 0.75
# Accuracy test en split 2 --> 0.706
# Accuracy test en split 3 --> 0.756
# Accuracy test en split 4 --> 0.756
# Accuracy test en split 5 --> 0.754
# Accuracy test en split 6 --> 0.752
# Accuracy test en split 7 --> 0.742
# Accuracy test en split 8 --> 0.756
# Accuracy test en split 9 --> 0.726
# Accuracy test en split 10 --> 0.756
# Time: 15.5s
# Accuracy medio -->  0.7454
#
# Número de muestras: 10000 // kernel: poly
# Accuracy test en split 1 --> 0.775
# Accuracy test en split 2 --> 0.765
# Accuracy test en split 3 --> 0.767
# Accuracy test en split 4 --> 0.774
# Accuracy test en split 5 --> 0.765
# Accuracy test en split 6 --> 0.761
# Accuracy test en split 7 --> 0.768
# Accuracy test en split 8 --> 0.774
# Accuracy test en split 9 --> 0.775
# Accuracy test en split 10 --> 0.767
# Time: 50.953125s
# Accuracy medio -->  0.7691000000000001
#
# Número de muestras: 15000 // kernel: poly
# Accuracy test en split 1 --> 0.7793333333333333
# Accuracy test en split 2 --> 0.7753333333333333
# Accuracy test en split 3 --> 0.768
# Accuracy test en split 4 --> 0.7726666666666666
# Accuracy test en split 5 --> 0.7666666666666667
# Accuracy test en split 6 --> 0.7766666666666666
# Accuracy test en split 7 --> 0.7826666666666666
# Accuracy test en split 8 --> 0.7686666666666667
# Accuracy test en split 9 --> 0.7766666666666666
# Accuracy test en split 10 --> 0.768
# Time: 1m 41.0s
# Accuracy medio -->  0.7734666666666666
#
# Número de muestras: 20000 // kernel: poly
# Accuracy test en split 1 --> 0.7795
# Accuracy test en split 2 --> 0.784
# Accuracy test en split 3 --> 0.786
# Accuracy test en split 4 --> 0.77
# Accuracy test en split 5 --> 0.776
# Accuracy test en split 6 --> 0.7795
# Accuracy test en split 7 --> 0.7765
# Accuracy test en split 8 --> 0.7835
# Accuracy test en split 9 --> 0.779
# Accuracy test en split 10 --> 0.777
# Time: 2m 48.453125s
# Accuracy medio -->  0.7790999999999999
#
# Número de muestras: 25000 // kernel: poly
# Accuracy test en split 1 --> 0.7912
# Accuracy test en split 2 --> 0.7844
# Accuracy test en split 3 --> 0.7836
# Accuracy test en split 4 --> 0.7916
# Accuracy test en split 5 --> 0.7864
# Accuracy test en split 6 --> 0.7824
# Accuracy test en split 7 --> 0.7836
# Accuracy test en split 8 --> 0.7924
# Accuracy test en split 9 --> 0.7812
# Accuracy test en split 10 --> 0.7852
# Time: 4m 1.75s
# Accuracy medio -->  0.7862
#
# Número de muestras: 30000 // kernel: poly
# Accuracy test en split 1 --> 0.78
# Accuracy test en split 2 --> 0.7886666666666666
# Accuracy test en split 3 --> 0.783
# Accuracy test en split 4 --> 0.791
# Accuracy test en split 5 --> 0.7796666666666666
# Accuracy test en split 6 --> 0.7906666666666666
# Accuracy test en split 7 --> 0.7816666666666666
# Accuracy test en split 8 --> 0.7836666666666666
# Accuracy test en split 9 --> 0.7883333333333333
# Accuracy test en split 10 --> 0.7776666666666666
# Time: 5m 48.578125s
# Accuracy medio -->  0.7844333333333333
#
# Número de muestras: 35000 // kernel: poly
# Accuracy test en split 1 --> 0.7865714285714286
# Accuracy test en split 2 --> 0.7848571428571428
# Accuracy test en split 3 --> 0.7857142857142857
# Accuracy test en split 4 --> 0.7854285714285715
# Accuracy test en split 5 --> 0.786
# Accuracy test en split 6 --> 0.7837142857142857
# Accuracy test en split 7 --> 0.7834285714285715
# Accuracy test en split 8 --> 0.7882857142857143
# Accuracy test en split 9 --> 0.788
# Accuracy test en split 10 --> 0.782
# Time: 7m 51.5625s
# Accuracy medio -->  0.7854
#
# Número de muestras: 40000 // kernel: poly
# Accuracy test en split 1 --> 0.785
# Accuracy test en split 2 --> 0.79525
# Accuracy test en split 3 --> 0.78925
# Accuracy test en split 4 --> 0.792
# Accuracy test en split 5 --> 0.79025
# Accuracy test en split 6 --> 0.792
# Accuracy test en split 7 --> 0.7865
# Accuracy test en split 8 --> 0.79
# Accuracy test en split 9 --> 0.793
# Accuracy test en split 10 --> 0.78825
# Time: 10m 6.921875s
# Accuracy medio -->  0.79015
#
# Número de muestras: 45000 // kernel: poly
# Accuracy test en split 1 --> 0.7906666666666666
# Accuracy test en split 2 --> 0.7946666666666666
# Accuracy test en split 3 --> 0.788
# Accuracy test en split 4 --> 0.7897777777777778
# Accuracy test en split 5 --> 0.7931111111111111
# Accuracy test en split 6 --> 0.7937777777777778
# Accuracy test en split 7 --> 0.7895555555555556
# Accuracy test en split 8 --> 0.7915555555555556
# Accuracy test en split 9 --> 0.7917777777777778
# Accuracy test en split 10 --> 0.7891111111111111
# Time: 12m 30.796875s
# Accuracy medio -->  0.7912000000000001
#
# Número de muestras: 50000 // kernel: poly
# Accuracy test en split 1 --> 0.7896
# Accuracy test en split 2 --> 0.7936
# Accuracy test en split 3 --> 0.7884
# Accuracy test en split 4 --> 0.7938
# Accuracy test en split 5 --> 0.794
# Accuracy test en split 6 --> 0.794
# Accuracy test en split 7 --> 0.7902
# Accuracy test en split 8 --> 0.7942
# Accuracy test en split 9 --> 0.7918
# Accuracy test en split 10 --> 0.79
# Time: 15m 51.25s
# Accuracy medio -->  0.79196
#
# Número de muestras: 55000 // kernel: poly
# Accuracy test en split 1 --> 0.7981818181818182
# Accuracy test en split 2 --> 0.7932727272727272
# Accuracy test en split 3 --> 0.7943636363636364
# Accuracy test en split 4 --> 0.794
# Accuracy test en split 5 --> 0.7896363636363637
# Accuracy test en split 6 --> 0.7952727272727272
# Accuracy test en split 7 --> 0.7909090909090909
# Accuracy test en split 8 --> 0.7912727272727272
# Accuracy test en split 9 --> 0.7930909090909091
# Accuracy test en split 10 --> 0.79
# Time: 19m 43.875s
# Accuracy medio -->  0.793
#
# Número de muestras: 60000 // kernel: poly
# Accuracy test en split 1 --> 0.7945
# Accuracy test en split 2 --> 0.8001666666666667
# Accuracy test en split 3 --> 0.7981666666666667
# Accuracy test en split 4 --> 0.7903333333333333
# Accuracy test en split 5 --> 0.7915
# Accuracy test en split 6 --> 0.7966666666666666
# Accuracy test en split 7 --> 0.7948333333333333
# Accuracy test en split 8 --> 0.7903333333333333
# Accuracy test en split 9 --> 0.7965
# Accuracy test en split 10 --> 0.7911666666666667
# Time: 25m 38.96875s
# Accuracy medio -->  0.7944166666666665

# %%
print(f'Lista de muestras {list_samples_poly} y lista de tiempos {list_times_poly}')
# Out:
# Lista de muestras [0, 1, 5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000] y lista de tiempos [0, 0, 15.5, 50.953125, 101.0, 168.453125, 241.75, 348.578125, 471.5625, 606.921875, 750.796875, 951.25, 1183.875, 1538.96875]

# %%
x_poly = list_samples_poly
y_poly = list_times_poly
# x_rbf = list_samples_rbf
# y_rbf = list_times_rbf
# #Generamos una grafica lineal para una recta en X
# plt.plot(x_poly, y_poly, label='Polinomial')
#Generamos otra grafica lineal para una X cuadratica
plt.plot(x_poly, y_poly, label='Gaussiana')

#Agregamos las etiquetas y añadimos una leyenda.
plt.xlabel('Muestras')
plt.ylabel('Tiempo (segundos)')
plt.title("Poly")
plt.legend()
plt.savefig('grafica_lineal.png')
plt.show()

# %%
#Metodo para graficar tiempos vs muestras de kernel rbf
list_samples_rbf = [0,1]
list_times_rbf = [0,0]
for sampl in range(6250, nSamples+1, 6250):
    show_samples = int(sampl * (1-nTest))
    print('\033[5;34m'+'Número de muestras:', show_samples, '// kernel: rbf','\033[0;m')
        
    df = data
    df = df[:sampl]
        
    X = df.drop(['act'], axis = 'columns')
    y = df.act
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=nTest, random_state=42)
        
    list_acc, time, best_model = Modulo_SVM.modl(SVC(kernel = 'rbf', decision_function_shape='ovo'), X_train, y_train, 10)
        
    mean_acc = np.mean(list_acc)
    list_samples_rbf.append(show_samples)
    list_times_rbf.append(time)
    
#     print(f'Lista de muestras {list_samples_rbf} y lista de tiempos {list_samples_rbf}')
        
    print('\033[5;32m'+'Accuracy medio --> ', mean_acc, '\n'+'\033[0;m')
# Out:
# Número de muestras: 5000 // kernel: rbf
# Accuracy test en split 1 --> 0.734
# Accuracy test en split 2 --> 0.708
# Accuracy test en split 3 --> 0.754
# Accuracy test en split 4 --> 0.75
# Accuracy test en split 5 --> 0.738
# Accuracy test en split 6 --> 0.736
# Accuracy test en split 7 --> 0.742
# Accuracy test en split 8 --> 0.746
# Accuracy test en split 9 --> 0.724
# Accuracy test en split 10 --> 0.754
# Time: 8.203125s
# Accuracy medio -->  0.7385999999999999
#
# Número de muestras: 10000 // kernel: rbf
# Accuracy test en split 1 --> 0.764
# Accuracy test en split 2 --> 0.756
# Accuracy test en split 3 --> 0.766
# Accuracy test en split 4 --> 0.768
# Accuracy test en split 5 --> 0.768
# Accuracy test en split 6 --> 0.743
# Accuracy test en split 7 --> 0.754
# Accuracy test en split 8 --> 0.759
# Accuracy test en split 9 --> 0.763
# Accuracy test en split 10 --> 0.759
# Time: 27.53125s
# Accuracy medio -->  0.76
#
# Número de muestras: 15000 // kernel: rbf
# Accuracy test en split 1 --> 0.7806666666666666
# Accuracy test en split 2 --> 0.7646666666666667
# Accuracy test en split 3 --> 0.772
# Accuracy test en split 4 --> 0.7666666666666667
# Accuracy test en split 5 --> 0.76
# Accuracy test en split 6 --> 0.7666666666666667
# Accuracy test en split 7 --> 0.7766666666666666
# Accuracy test en split 8 --> 0.756
# Accuracy test en split 9 --> 0.774
# Accuracy test en split 10 --> 0.7686666666666667
# Time: 55.984375s
# Accuracy medio -->  0.7686
#
# Número de muestras: 20000 // kernel: rbf
# Accuracy test en split 1 --> 0.7705
# Accuracy test en split 2 --> 0.7745
# Accuracy test en split 3 --> 0.7805
# Accuracy test en split 4 --> 0.771
# Accuracy test en split 5 --> 0.7705
# Accuracy test en split 6 --> 0.772
# Accuracy test en split 7 --> 0.771
# Accuracy test en split 8 --> 0.7855
# Accuracy test en split 9 --> 0.7735
# Accuracy test en split 10 --> 0.7775
# Time: 1m 35.671875s
# Accuracy medio -->  0.7746500000000001
#
# Número de muestras: 25000 // kernel: rbf
# Accuracy test en split 1 --> 0.7828
# Accuracy test en split 2 --> 0.7784
# Accuracy test en split 3 --> 0.7832
# Accuracy test en split 4 --> 0.7792
# Accuracy test en split 5 --> 0.7808
# Accuracy test en split 6 --> 0.7656
# Accuracy test en split 7 --> 0.7768
# Accuracy test en split 8 --> 0.7884
# Accuracy test en split 9 --> 0.7724
# Accuracy test en split 10 --> 0.776
# Time: 2m 22.328125s
# Accuracy medio -->  0.7783599999999999
#
# Número de muestras: 30000 // kernel: rbf
# Accuracy test en split 1 --> 0.777
# Accuracy test en split 2 --> 0.7813333333333333
# Accuracy test en split 3 --> 0.775
# Accuracy test en split 4 --> 0.785
# Accuracy test en split 5 --> 0.777
# Accuracy test en split 6 --> 0.7843333333333333
# Accuracy test en split 7 --> 0.7776666666666666
# Accuracy test en split 8 --> 0.7773333333333333
# Accuracy test en split 9 --> 0.7823333333333333
# Accuracy test en split 10 --> 0.7756666666666666
# Time: 3m 21.15625s
# Accuracy medio -->  0.7792666666666667
#
# Número de muestras: 35000 // kernel: rbf
# Accuracy test en split 1 --> 0.7791428571428571
# Accuracy test en split 2 --> 0.7802857142857142
# Accuracy test en split 3 --> 0.7837142857142857
# Accuracy test en split 4 --> 0.7791428571428571
# Accuracy test en split 5 --> 0.78
# Accuracy test en split 6 --> 0.7822857142857143
# Accuracy test en split 7 --> 0.7851428571428571
# Accuracy test en split 8 --> 0.7828571428571428
# Accuracy test en split 9 --> 0.7834285714285715
# Accuracy test en split 10 --> 0.7802857142857142
# Time: 4m 30.78125s
# Accuracy medio -->  0.7816285714285715
#
# Número de muestras: 40000 // kernel: rbf
# Accuracy test en split 1 --> 0.7825
# Accuracy test en split 2 --> 0.792
# Accuracy test en split 3 --> 0.78425
# Accuracy test en split 4 --> 0.7835
# Accuracy test en split 5 --> 0.7875
# Accuracy test en split 6 --> 0.78975
# Accuracy test en split 7 --> 0.78325
# Accuracy test en split 8 --> 0.786
# Accuracy test en split 9 --> 0.7815
# Accuracy test en split 10 --> 0.7885
# Time: 5m 45.953125s
# Accuracy medio -->  0.785875
#
# Número de muestras: 45000 // kernel: rbf
# Accuracy test en split 1 --> 0.7871111111111111
# Accuracy test en split 2 --> 0.7902222222222223
# Accuracy test en split 3 --> 0.7853333333333333
# Accuracy test en split 4 --> 0.788
# Accuracy test en split 5 --> 0.7855555555555556
# Accuracy test en split 6 --> 0.7911111111111111
# Accuracy test en split 7 --> 0.7862222222222223
# Accuracy test en split 8 --> 0.7862222222222223
# Accuracy test en split 9 --> 0.7904444444444444
# Accuracy test en split 10 --> 0.7904444444444444
# Time: 7m 15.375s
# Accuracy medio -->  0.7880666666666667
#
# Número de muestras: 50000 // kernel: rbf
# Accuracy test en split 1 --> 0.7884
# Accuracy test en split 2 --> 0.7898
# Accuracy test en split 3 --> 0.7886
# Accuracy test en split 4 --> 0.7918
# Accuracy test en split 5 --> 0.79
# Accuracy test en split 6 --> 0.7938
# Accuracy test en split 7 --> 0.7858
# Accuracy test en split 8 --> 0.7928
# Accuracy test en split 9 --> 0.7918
# Accuracy test en split 10 --> 0.7896
# Time: 8m 58.71875s
# Accuracy medio -->  0.79024
#
# Número de muestras: 55000 // kernel: rbf
# Accuracy test en split 1 --> 0.7952727272727272
# Accuracy test en split 2 --> 0.7909090909090909
# Accuracy test en split 3 --> 0.7934545454545454
# Accuracy test en split 4 --> 0.7901818181818182
# Accuracy test en split 5 --> 0.7923636363636364
# Accuracy test en split 6 --> 0.7950909090909091
# Accuracy test en split 7 --> 0.79
# Accuracy test en split 8 --> 0.7869090909090909
# Accuracy test en split 9 --> 0.7963636363636364
# Accuracy test en split 10 --> 0.7907272727272727
# Time: 11m 9.75s
# Accuracy medio -->  0.7921272727272728
#
# Número de muestras: 60000 // kernel: rbf
# Accuracy test en split 1 --> 0.7981666666666667
# Accuracy test en split 2 --> 0.7978333333333333
# Accuracy test en split 3 --> 0.7945
# Accuracy test en split 4 --> 0.7881666666666667
# Accuracy test en split 5 --> 0.7923333333333333
# Accuracy test en split 6 --> 0.7938333333333333
# Accuracy test en split 7 --> 0.7918333333333333
# Accuracy test en split 8 --> 0.7896666666666666
# Accuracy test en split 9 --> 0.7963333333333333
# Accuracy test en split 10 --> 0.7956666666666666
# Time: 13m 47.53125s
# Accuracy medio -->  0.7938333333333333

# %%
print(f'Lista de muestras {list_samples_rbf} y lista de tiempos {list_samples_rbf}')
# Out:
# Lista de muestras [0, 1, 5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000] y lista de tiempos [0, 1, 5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000]

# %%
# x_poly = list_samples_poly
# y_poly = list_times_poly
x_rbf = list_samples_rbf
y_rbf = list_times_rbf
# #Generamos una grafica lineal para una recta en X
# plt.plot(x_poly, y_poly, label='Polinomial')
#Generamos otra grafica lineal para una X cuadratica
plt.plot(x_rbf, y_rbf, label='Gaussiana')

#Agregamos las etiquetas y añadimos una leyenda.
plt.xlabel('Muestras')
plt.ylabel('Tiempo (segundos)')
plt.title("RBF")
plt.legend()
plt.savefig('grafica_lineal.png')
plt.show()

# %%
# x_values = ['Walking', 'Running', 'Going up', 'Going down', 'Sitting', 'Sitting down', 'Standing up', 'Standing', 
#                'Bicycling', 'Up by elevator',  'Down by elevator',  'Sitting in car']
# # x_values = ['Walking', 'Running', 'Going up', 'Going down', 'Sitting', 'Sitting down', 'Standing up', 'Standing', 
# #             'Up by elevator',  'Down by elevator']
# y_values = []
# y_values.append((df[(df.act == 1)]).shape[0])
# y_values.append((df[(df.act == 2)]).shape[0])
# y_values.append((df[(df.act == 3)]).shape[0])
# y_values.append((df[(df.act == 4)]).shape[0])
# y_values.append((df[(df.act == 5)]).shape[0])
# y_values.append((df[(df.act == 6)]).shape[0])
# y_values.append((df[(df.act == 7)]).shape[0])
# y_values.append((df[(df.act == 8)]).shape[0])
# y_values.append((df[(df.act == 9)]).shape[0])
# y_values.append((df[(df.act == 10)]).shape[0])
# y_values.append((df[(df.act == 11)]).shape[0])
# y_values.append((df[(df.act == 12)]).shape[0])
# print(f'num of samples: {sum(y_values)}')
# print(y_values)
# plt.figure(figsize=(20,10))
# plt.bar(x_values, y_values, width=0.8)

# %%
# print(f'Lista de muestras {list_samples_poly} y lista de tiempos {list_times_poly}')
# x_poly = list_samples_poly
# y_poly = list_times_poly
# #Generamos una grafica lineal para una recta en X
# plt.plot(x_poly, y_poly, label='Polinomial')

# #Agregamos las etiquetas y añadimos una leyenda.
# plt.xlabel('Muestras')
# plt.ylabel('Tiempo')
# plt.title("Simple Plot")
# plt.legend()
# plt.savefig('grafica_lineal.png')
# plt.show()

# %%
# list_samples_poly_s = list_samples_poly
# list_times_poly_s = list_times_poly
# list_samples_rbf_s = list_samples_rbf
# list_times_rbf_s = list_times_rbf

x_poly = list_samples_poly
y_poly = list_times_poly
x_rbf = list_samples_rbf
y_rbf = list_times_rbf
#Generamos una grafica lineal para una recta en X
plt.plot(x_poly, y_poly, label='Polinomial')
#Generamos otra grafica lineal para una X cuadratica
plt.plot(x_rbf, y_rbf, label='Gaussiana')

#Agregamos las etiquetas y añadimos una leyenda.
plt.xlabel('Muestras')
plt.ylabel('Tiempo (segundos)')
plt.title("Simple Plot")
plt.legend()
plt.savefig('grafica_lineal.png')
plt.show()

# %%
# list_samples_poly_s = [round(samp/60) for samp in  list_samples_poly]
# list_samples_poly_s
