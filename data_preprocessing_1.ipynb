# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaime44/TFM/blob/main/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://files.grouplens.org/datasets/movielens/ml-25m-README.html

# %%
import sys
import os


# Comprueba si el código se está ejecutando en Google Colab
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

path_absolute = ''
if IN_COLAB:
    print("El código se está ejecutando en Google Colab.")
    from google.colab import drive

    drive.mount('/content/drive')
    path_absolute = '/content/drive/Othercomputers/Mi portátil/TFM/WorkSpace/TFM/'

    # Cambia al directorio de tu carpeta en Google Drive
    os.chdir(path_absolute)

    # Lista los archivos y carpetas en el directorio actual
    contenido_carpeta = os.listdir(path_absolute)
    print("Contenido de la carpeta en Google Drive:")
    print(contenido_carpeta)
else:
    print("El código se está ejecutando en un entorno local.")
    path_absolute = 'C:/Users/jaime/OneDrive - Universidad de Málaga/Escritorio/UNIR/TFM/WorkSpace/TFM/ml-25m/'
# Out:
# El código se está ejecutando en Google Colab.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Contenido de la carpeta en Google Drive:
# ['data_preprocessing.ipynb', '.git', 'TMDb_updated.CSV', 'Tema 8 - SVM ejemplo.ipynb', 'README.md', 'CuadernoEjerciciosTema8-Solucion.ipynb', 'movie_dataset_dummy.csv', 'svm_rs.ipynb', '.gitignore', 'Others models', 'data_preprocessing_prev.ipynb', 'ml-25m']

# %%
import pandas as pd

# %%
nameDataFrame = 'ml-25m/movies_rating.csv'

# %%
dataFrame = pd.read_csv(path_absolute+nameDataFrame, sep=',')
print(dataFrame.shape)
print(dataFrame.info())
dataFrame.head()
# Out:
# (8949372, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8949372 entries, 0 to 8949371
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   userId           int64
#  1   movieId          int64
#  2   rating           float64
#  3   timestamp_scr    int64
#  4   movie_tags_user  object
#  5   timestamp_tags   int64
#  6   title            object
#  7   genres           object
#  8   imdbId           int64
#  9   tmdbId           float64
#  10  tagId            int64
#  11  relevance        float64
#  12  tag_genome       object
# dtypes: float64(3), int64(6), object(4)
# memory usage: 887.6+ MB
# None
#    userId  movieId  rating  timestamp_scr   movie_tags_user  timestamp_tags  \
# 0       3      260     4.0     1439472239           classic      1439472355
# 1       3      260     4.0     1439472239            sci-fi      1439472256
# 2     264      260     3.0     1543390081            aliens      1543390134
# 3     264      260     3.0     1543390081  oldie but goodie      1543390130
# 4     264      260     3.0     1543390081        scifi cult      1543390105
#
#                                        title                   genres  imdbId  \
# 0  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi   76759
# 1  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi   76759
# 2  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi   76759
# 3  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi   76759
# 4  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi   76759
#
#    tmdbId  tagId  relevance tag_genome
# 0    11.0     75    0.26025        art
# 1    11.0     75    0.26025        art
# 2    11.0     75    0.26025        art
# 3    11.0     75    0.26025        art
# 4    11.0     75    0.26025        art

# %%
# Elimino las columnas de timestamp puesto que tenemos dos valoes distintos una para el moenmnto en el que hizo la valoración y otro en el que se etiqueto la pelicula por el usuario. Se entiende que no son datos relevantes
# y pueden no aportar nada, aún así se puede hacer un pre-procesado con y sin timestamp y ver si ayudan o emperon estos datos, para ello hay que hacer un estudio del conjunto de datos.
#Hay algunas columnas de ID como imdbId tmdbId o tagId movieId que hay que ver si los elimiono a los mantengo a lo mejor es interesante mantener alguno que identifique la pelicula para cuando se haga algún
# enrenamientotner un valor que no  se a un strng(nombre) par aidentificar las peliculas. Lo que esta claro que no puedo tener 3 identificadores para las peliculas. El idice de tag si que no me vale para nada.

# %%
# tag_df_mezclado_tags_ratings_movies_links_genMov --> metadatos creados por los usuarios

# %%
# Renombro algunas columnas para mayor comodidad
# dataFrame.rename(columns={'tag_df_mezclado_tags_ratings_movies_links_genMov': 'movie_tags_user', 'tag_etiquetas_genómicas': 'tag_genome','timestamp_valoraciones': 'timestamp_scr', 'timestamp_etiquetas': 'timestamp_tags'}, inplace=True)

# %%
# dataFrame.to_csv(path_absolute+'movies_rating.csv', index=False)
