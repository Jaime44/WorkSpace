# %%
import os
import sys
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

#-------------------------------------------------------------------------------------

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Embedding, Flatten, Dense, Concatenate

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
# Comprueba si el código se está ejecutando en Google Colab
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

path_absolute = ''
if IN_COLAB:
    print("El código se está ejecutando en Google Colab.")
    from google.colab import drive

    drive.mount('/content/drive')
    path_absolute = '/content/drive/Othercomputers/Mi_portátil/TFM/WorkSpace/'

    # Cambia al directorio de tu carpeta en Google Drive
    os.chdir(path_absolute)

    # Lista los archivos y carpetas en el directorio actual
    contenido_carpeta = os.listdir(path_absolute)
    print("Contenido de la carpeta en Google Drive:")
    print(contenido_carpeta)
else:
    print("El código se está ejecutando en un entorno local.")
    path_absolute = 'C:/Users/jaime/OneDrive - Universidad de Málaga/Escritorio/UNIR/TFM/WorkSpace/'

path_file = 'df_movies_rating_2.csv'

# %%
dataFrame = pd.read_csv(path_absolute+path_file, sep=',')
data = dataFrame.copy()

# %%
# Especifica el tamaño de la muestra que deseas obtener
tamano_muestra = 500  # Cambia esto al tamaño de muestra que desees
# Obtiene una muestra aleatoria uniforme del DataFrame
data = data.sample(n=tamano_muestra, random_state=42)  # random_state para reproducibilidad
data.head()

# %% [markdown]
# MODELO CON KERAS

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Concatenate

# Dividir datos en entrenamiento y prueba
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Normalizar datos
scaler = StandardScaler()
train_data_scaled = scaler.fit_transform(train_data[['userId', 'movieId', 'timestamp_scr', 'tag_encoded']])
test_data_scaled = scaler.transform(test_data[['userId', 'movieId', 'timestamp_scr', 'tag_encoded']])
train_data

# Construir el modelo de recomendación
model = Sequential()

# Capas de entrada para datos numéricos
model.add(Dense(64, activation='relu', input_shape=(train_data_scaled.shape[1],)))
model.add(Dense(32, activation='relu'))

# Capa de salida para predicción de puntuación
model.add(Dense(1, activation='linear'))

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Entrenar el modelo
model.fit(train_data_scaled, train_data['rating'], epochs=150, batch_size=128, validation_split=0.2)

# Evaluar el modelo en el conjunto de prueba
loss, mae = model.evaluate(test_data_scaled, test_data['rating'])
print(f'Mean Absolute Error on Test Data: {mae}')

# Realizar predicciones
predictions = model.predict(test_data_scaled)

# Puedes utilizar estas predicciones para recomendar películas al usuario
# por ejemplo, recomendando las películas con las puntuaciones predichas más altas.
# Out:
# Epoch 1/150
# 3/3 [==============================] - 1s 173ms/step - loss: 17.0595 - mean_absolute_error: 4.0078 - val_loss: 17.0398 - val_mean_absolute_error: 4.0508
# Epoch 2/150
# 3/3 [==============================] - 0s 28ms/step - loss: 16.0809 - mean_absolute_error: 3.8821 - val_loss: 16.0393 - val_mean_absolute_error: 3.9254
# Epoch 3/150
# 3/3 [==============================] - 0s 28ms/step - loss: 15.1664 - mean_absolute_error: 3.7603 - val_loss: 15.1090 - val_mean_absolute_error: 3.8046
# Epoch 4/150
# 3/3 [==============================] - 0s 52ms/step - loss: 14.3068 - mean_absolute_error: 3.6418 - val_loss: 14.2325 - val_mean_absolute_error: 3.6866
# Epoch 5/150
# 3/3 [==============================] - 0s 36ms/step - loss: 13.5021 - mean_absolute_error: 3.5264 - val_loss: 13.3944 - val_mean_absolute_error: 3.5693
# Epoch 6/150
# 3/3 [==============================] - 0s 114ms/step - loss: 12.7303 - mean_absolute_error: 3.4106 - val_loss: 12.5609 - val_mean_absolute_error: 3.4483
# Epoch 7/150
# 3/3 [==============================] - 0s 73ms/step - loss: 11.9478 - mean_absolute_error: 3.2937 - val_loss: 11.7298 - val_mean_absolute_error: 3.3226
# Epoch 8/150
# 3/3 [==============================] - 0s 40ms/step - loss: 11.1754 - mean_absolute_error: 3.1702 - val_loss: 10.8864 - val_mean_absolute_error: 3.1895
# Epoch 9/150
# 3/3 [==============================] - 0s 69ms/step - loss: 10.3873 - mean_absolute_error: 3.0425 - val_loss: 10.0248 - val_mean_absolute_error: 3.0464
# Epoch 10/150
# 3/3 [==============================] - 0s 52ms/step - loss: 9.5830 - mean_absolute_error: 2.9055 - val_loss: 9.1325 - val_mean_absolute_error: 2.8899
# Epoch 11/150
# 3/3 [==============================] - 0s 67ms/step - loss: 8.7668 - mean_absolute_error: 2.7631 - val_loss: 8.2041 - val_mean_absolute_error: 2.7161
# Epoch 12/150
# 3/3 [==============================] - 0s 33ms/step - loss: 7.9104 - mean_absolute_error: 2.6046 - val_loss: 7.2529 - val_mean_absolute_error: 2.5287
# Epoch 13/150
# 3/3 [==============================] - 0s 35ms/step - loss: 7.0565 - mean_absolute_error: 2.4407 - val_loss: 6.3081 - val_mean_absolute_error: 2.3260
# Epoch 14/150
# 3/3 [==============================] - 0s 36ms/step - loss: 6.2283 - mean_absolute_error: 2.2746 - val_loss: 5.4008 - val_mean_absolute_error: 2.1170
# Epoch 15/150
# 3/3 [==============================] - 0s 35ms/step - loss: 5.4283 - mean_absolute_error: 2.1051 - val_loss: 4.5652 - val_mean_absolute_error: 1.9068
# Epoch 16/150
# 3/3 [==============================] - 0s 36ms/step - loss: 4.6965 - mean_absolute_error: 1.9381 - val_loss: 3.8228 - val_mean_absolute_error: 1.7027
# Epoch 17/150
# 3/3 [==============================] - 0s 37ms/step - loss: 4.0616 - mean_absolute_error: 1.7773 - val_loss: 3.1926 - val_mean_absolute_error: 1.5382
# Epoch 18/150
# 3/3 [==============================] - 0s 42ms/step - loss: 3.5072 - mean_absolute_error: 1.6294 - val_loss: 2.6828 - val_mean_absolute_error: 1.4123
# Epoch 19/150
# 3/3 [==============================] - 0s 95ms/step - loss: 3.0652 - mean_absolute_error: 1.4923 - val_loss: 2.2858 - val_mean_absolute_error: 1.3068
# Epoch 20/150
# 3/3 [==============================] - 0s 56ms/step - loss: 2.6992 - mean_absolute_error: 1.3768 - val_loss: 1.9958 - val_mean_absolute_error: 1.2198
# Epoch 21/150
# 3/3 [==============================] - 0s 57ms/step - loss: 2.4487 - mean_absolute_error: 1.2951 - val_loss: 1.7880 - val_mean_absolute_error: 1.1489
# Epoch 22/150
# 3/3 [==============================] - 0s 48ms/step - loss: 2.2540 - mean_absolute_error: 1.2251 - val_loss: 1.6423 - val_mean_absolute_error: 1.0893
# Epoch 23/150
# 3/3 [==============================] - 0s 57ms/step - loss: 2.0960 - mean_absolute_error: 1.1662 - val_loss: 1.5368 - val_mean_absolute_error: 1.0439
# Epoch 24/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.9918 - mean_absolute_error: 1.1249 - val_loss: 1.4555 - val_mean_absolute_error: 1.0097
# Epoch 25/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.9108 - mean_absolute_error: 1.0916 - val_loss: 1.3899 - val_mean_absolute_error: 0.9811
# Epoch 26/150
# 3/3 [==============================] - 0s 35ms/step - loss: 1.8318 - mean_absolute_error: 1.0608 - val_loss: 1.3338 - val_mean_absolute_error: 0.9559
# Epoch 27/150
# 3/3 [==============================] - 0s 32ms/step - loss: 1.7670 - mean_absolute_error: 1.0383 - val_loss: 1.2824 - val_mean_absolute_error: 0.9315
# Epoch 28/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.7176 - mean_absolute_error: 1.0187 - val_loss: 1.2354 - val_mean_absolute_error: 0.9079
# Epoch 29/150
# 3/3 [==============================] - 0s 30ms/step - loss: 1.6715 - mean_absolute_error: 1.0039 - val_loss: 1.1962 - val_mean_absolute_error: 0.8882
# Epoch 30/150
# 3/3 [==============================] - 0s 70ms/step - loss: 1.6288 - mean_absolute_error: 0.9931 - val_loss: 1.1660 - val_mean_absolute_error: 0.8738
# Epoch 31/150
# 3/3 [==============================] - 0s 80ms/step - loss: 1.6019 - mean_absolute_error: 0.9873 - val_loss: 1.1435 - val_mean_absolute_error: 0.8652
# Epoch 32/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.5739 - mean_absolute_error: 0.9820 - val_loss: 1.1275 - val_mean_absolute_error: 0.8607
# Epoch 33/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5581 - mean_absolute_error: 0.9786 - val_loss: 1.1150 - val_mean_absolute_error: 0.8577
# Epoch 34/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.5444 - mean_absolute_error: 0.9752 - val_loss: 1.1060 - val_mean_absolute_error: 0.8557
# Epoch 35/150
# 3/3 [==============================] - 0s 53ms/step - loss: 1.5310 - mean_absolute_error: 0.9719 - val_loss: 1.0989 - val_mean_absolute_error: 0.8547
# Epoch 36/150
# 3/3 [==============================] - 0s 45ms/step - loss: 1.5229 - mean_absolute_error: 0.9707 - val_loss: 1.0921 - val_mean_absolute_error: 0.8530
# Epoch 37/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5153 - mean_absolute_error: 0.9693 - val_loss: 1.0844 - val_mean_absolute_error: 0.8501
# Epoch 38/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.5071 - mean_absolute_error: 0.9668 - val_loss: 1.0774 - val_mean_absolute_error: 0.8476
# Epoch 39/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.4991 - mean_absolute_error: 0.9643 - val_loss: 1.0704 - val_mean_absolute_error: 0.8449
# Epoch 40/150
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4915 - mean_absolute_error: 0.9613 - val_loss: 1.0619 - val_mean_absolute_error: 0.8412
# Epoch 41/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.4839 - mean_absolute_error: 0.9578 - val_loss: 1.0538 - val_mean_absolute_error: 0.8376
# Epoch 42/150
# 3/3 [==============================] - 0s 40ms/step - loss: 1.4764 - mean_absolute_error: 0.9550 - val_loss: 1.0470 - val_mean_absolute_error: 0.8345
# Epoch 43/150
# 3/3 [==============================] - 0s 29ms/step - loss: 1.4688 - mean_absolute_error: 0.9520 - val_loss: 1.0402 - val_mean_absolute_error: 0.8313
# Epoch 44/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4623 - mean_absolute_error: 0.9493 - val_loss: 1.0330 - val_mean_absolute_error: 0.8279
# Epoch 45/150
# 3/3 [==============================] - 0s 34ms/step - loss: 1.4549 - mean_absolute_error: 0.9464 - val_loss: 1.0264 - val_mean_absolute_error: 0.8248
# Epoch 46/150
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4477 - mean_absolute_error: 0.9432 - val_loss: 1.0195 - val_mean_absolute_error: 0.8213
# Epoch 47/150
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4415 - mean_absolute_error: 0.9406 - val_loss: 1.0125 - val_mean_absolute_error: 0.8178
# Epoch 48/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4352 - mean_absolute_error: 0.9382 - val_loss: 1.0076 - val_mean_absolute_error: 0.8157
# Epoch 49/150
# 3/3 [==============================] - 0s 40ms/step - loss: 1.4305 - mean_absolute_error: 0.9360 - val_loss: 1.0010 - val_mean_absolute_error: 0.8123
# Epoch 50/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.4219 - mean_absolute_error: 0.9324 - val_loss: 0.9978 - val_mean_absolute_error: 0.8115
# Epoch 51/150
# 3/3 [==============================] - 0s 100ms/step - loss: 1.4157 - mean_absolute_error: 0.9309 - val_loss: 0.9952 - val_mean_absolute_error: 0.8112
# Epoch 52/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4097 - mean_absolute_error: 0.9294 - val_loss: 0.9925 - val_mean_absolute_error: 0.8110
# Epoch 53/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4040 - mean_absolute_error: 0.9288 - val_loss: 0.9908 - val_mean_absolute_error: 0.8119
# Epoch 54/150
# 3/3 [==============================] - 0s 40ms/step - loss: 1.3969 - mean_absolute_error: 0.9272 - val_loss: 0.9869 - val_mean_absolute_error: 0.8111
# Epoch 55/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3910 - mean_absolute_error: 0.9255 - val_loss: 0.9836 - val_mean_absolute_error: 0.8104
# Epoch 56/150
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3840 - mean_absolute_error: 0.9237 - val_loss: 0.9822 - val_mean_absolute_error: 0.8114
# Epoch 57/150
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3793 - mean_absolute_error: 0.9226 - val_loss: 0.9803 - val_mean_absolute_error: 0.8119
# Epoch 58/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3734 - mean_absolute_error: 0.9212 - val_loss: 0.9766 - val_mean_absolute_error: 0.8115
# Epoch 59/150
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3675 - mean_absolute_error: 0.9196 - val_loss: 0.9725 - val_mean_absolute_error: 0.8104
# Epoch 60/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3618 - mean_absolute_error: 0.9177 - val_loss: 0.9677 - val_mean_absolute_error: 0.8086
# Epoch 61/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.3559 - mean_absolute_error: 0.9155 - val_loss: 0.9615 - val_mean_absolute_error: 0.8055
# Epoch 62/150
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3500 - mean_absolute_error: 0.9127 - val_loss: 0.9550 - val_mean_absolute_error: 0.8021
# Epoch 63/150
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3435 - mean_absolute_error: 0.9102 - val_loss: 0.9488 - val_mean_absolute_error: 0.7985
# Epoch 64/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.3379 - mean_absolute_error: 0.9071 - val_loss: 0.9411 - val_mean_absolute_error: 0.7935
# Epoch 65/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3328 - mean_absolute_error: 0.9040 - val_loss: 0.9337 - val_mean_absolute_error: 0.7885
# Epoch 66/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3289 - mean_absolute_error: 0.9016 - val_loss: 0.9284 - val_mean_absolute_error: 0.7854
# Epoch 67/150
# 3/3 [==============================] - 0s 48ms/step - loss: 1.3233 - mean_absolute_error: 0.8991 - val_loss: 0.9254 - val_mean_absolute_error: 0.7849
# Epoch 68/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.3172 - mean_absolute_error: 0.8975 - val_loss: 0.9235 - val_mean_absolute_error: 0.7854
# Epoch 69/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3115 - mean_absolute_error: 0.8959 - val_loss: 0.9207 - val_mean_absolute_error: 0.7852
# Epoch 70/150
# 3/3 [==============================] - 0s 54ms/step - loss: 1.3062 - mean_absolute_error: 0.8945 - val_loss: 0.9186 - val_mean_absolute_error: 0.7855
# Epoch 71/150
# 3/3 [==============================] - 0s 32ms/step - loss: 1.3003 - mean_absolute_error: 0.8928 - val_loss: 0.9156 - val_mean_absolute_error: 0.7850
# Epoch 72/150
# 3/3 [==============================] - 0s 32ms/step - loss: 1.2952 - mean_absolute_error: 0.8913 - val_loss: 0.9125 - val_mean_absolute_error: 0.7843
# Epoch 73/150
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2898 - mean_absolute_error: 0.8896 - val_loss: 0.9092 - val_mean_absolute_error: 0.7838
# Epoch 74/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.2843 - mean_absolute_error: 0.8880 - val_loss: 0.9058 - val_mean_absolute_error: 0.7828
# Epoch 75/150
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2797 - mean_absolute_error: 0.8863 - val_loss: 0.9031 - val_mean_absolute_error: 0.7825
# Epoch 76/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.2745 - mean_absolute_error: 0.8844 - val_loss: 0.8982 - val_mean_absolute_error: 0.7801
# Epoch 77/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.2708 - mean_absolute_error: 0.8825 - val_loss: 0.8929 - val_mean_absolute_error: 0.7771
# Epoch 78/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.2641 - mean_absolute_error: 0.8797 - val_loss: 0.8890 - val_mean_absolute_error: 0.7757
# Epoch 79/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.2593 - mean_absolute_error: 0.8780 - val_loss: 0.8866 - val_mean_absolute_error: 0.7753
# Epoch 80/150
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2541 - mean_absolute_error: 0.8764 - val_loss: 0.8835 - val_mean_absolute_error: 0.7742
# Epoch 81/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.2492 - mean_absolute_error: 0.8748 - val_loss: 0.8820 - val_mean_absolute_error: 0.7745
# Epoch 82/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.2441 - mean_absolute_error: 0.8731 - val_loss: 0.8794 - val_mean_absolute_error: 0.7739
# Epoch 83/150
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2394 - mean_absolute_error: 0.8713 - val_loss: 0.8762 - val_mean_absolute_error: 0.7723
# Epoch 84/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.2335 - mean_absolute_error: 0.8699 - val_loss: 0.8762 - val_mean_absolute_error: 0.7734
# Epoch 85/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.2289 - mean_absolute_error: 0.8695 - val_loss: 0.8740 - val_mean_absolute_error: 0.7728
# Epoch 86/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.2236 - mean_absolute_error: 0.8681 - val_loss: 0.8697 - val_mean_absolute_error: 0.7702
# Epoch 87/150
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2189 - mean_absolute_error: 0.8660 - val_loss: 0.8633 - val_mean_absolute_error: 0.7660
# Epoch 88/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.2130 - mean_absolute_error: 0.8628 - val_loss: 0.8575 - val_mean_absolute_error: 0.7625
# Epoch 89/150
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2078 - mean_absolute_error: 0.8603 - val_loss: 0.8519 - val_mean_absolute_error: 0.7595
# Epoch 90/150
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2034 - mean_absolute_error: 0.8578 - val_loss: 0.8464 - val_mean_absolute_error: 0.7565
# Epoch 91/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1984 - mean_absolute_error: 0.8550 - val_loss: 0.8422 - val_mean_absolute_error: 0.7547
# Epoch 92/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.1937 - mean_absolute_error: 0.8537 - val_loss: 0.8417 - val_mean_absolute_error: 0.7567
# Epoch 93/150
# 3/3 [==============================] - 0s 76ms/step - loss: 1.1892 - mean_absolute_error: 0.8533 - val_loss: 0.8404 - val_mean_absolute_error: 0.7568
# Epoch 94/150
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1825 - mean_absolute_error: 0.8513 - val_loss: 0.8361 - val_mean_absolute_error: 0.7539
# Epoch 95/150
# 3/3 [==============================] - 0s 74ms/step - loss: 1.1776 - mean_absolute_error: 0.8491 - val_loss: 0.8302 - val_mean_absolute_error: 0.7503
# Epoch 96/150
# 3/3 [==============================] - 0s 58ms/step - loss: 1.1732 - mean_absolute_error: 0.8469 - val_loss: 0.8244 - val_mean_absolute_error: 0.7470
# Epoch 97/150
# 3/3 [==============================] - 0s 67ms/step - loss: 1.1690 - mean_absolute_error: 0.8449 - val_loss: 0.8198 - val_mean_absolute_error: 0.7447
# Epoch 98/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.1636 - mean_absolute_error: 0.8432 - val_loss: 0.8164 - val_mean_absolute_error: 0.7431
# Epoch 99/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.1592 - mean_absolute_error: 0.8418 - val_loss: 0.8130 - val_mean_absolute_error: 0.7419
# Epoch 100/150
# 3/3 [==============================] - 0s 53ms/step - loss: 1.1540 - mean_absolute_error: 0.8399 - val_loss: 0.8091 - val_mean_absolute_error: 0.7405
# Epoch 101/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1495 - mean_absolute_error: 0.8384 - val_loss: 0.8062 - val_mean_absolute_error: 0.7397
# Epoch 102/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.1445 - mean_absolute_error: 0.8369 - val_loss: 0.8020 - val_mean_absolute_error: 0.7378
# Epoch 103/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1407 - mean_absolute_error: 0.8357 - val_loss: 0.7995 - val_mean_absolute_error: 0.7373
# Epoch 104/150
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1360 - mean_absolute_error: 0.8341 - val_loss: 0.7949 - val_mean_absolute_error: 0.7352
# Epoch 105/150
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1309 - mean_absolute_error: 0.8325 - val_loss: 0.7909 - val_mean_absolute_error: 0.7339
# Epoch 106/150
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1267 - mean_absolute_error: 0.8311 - val_loss: 0.7863 - val_mean_absolute_error: 0.7317
# Epoch 107/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.1220 - mean_absolute_error: 0.8294 - val_loss: 0.7808 - val_mean_absolute_error: 0.7289
# Epoch 108/150
# 3/3 [==============================] - 0s 34ms/step - loss: 1.1181 - mean_absolute_error: 0.8282 - val_loss: 0.7789 - val_mean_absolute_error: 0.7283
# Epoch 109/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1135 - mean_absolute_error: 0.8270 - val_loss: 0.7757 - val_mean_absolute_error: 0.7268
# Epoch 110/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.1090 - mean_absolute_error: 0.8257 - val_loss: 0.7732 - val_mean_absolute_error: 0.7261
# Epoch 111/150
# 3/3 [==============================] - 0s 120ms/step - loss: 1.1048 - mean_absolute_error: 0.8244 - val_loss: 0.7697 - val_mean_absolute_error: 0.7241
# Epoch 112/150
# 3/3 [==============================] - 0s 124ms/step - loss: 1.1005 - mean_absolute_error: 0.8225 - val_loss: 0.7663 - val_mean_absolute_error: 0.7219
# Epoch 113/150
# 3/3 [==============================] - 0s 78ms/step - loss: 1.0958 - mean_absolute_error: 0.8208 - val_loss: 0.7642 - val_mean_absolute_error: 0.7209
# Epoch 114/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0911 - mean_absolute_error: 0.8190 - val_loss: 0.7596 - val_mean_absolute_error: 0.7186
# Epoch 115/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0874 - mean_absolute_error: 0.8172 - val_loss: 0.7552 - val_mean_absolute_error: 0.7166
# Epoch 116/150
# 3/3 [==============================] - 0s 35ms/step - loss: 1.0831 - mean_absolute_error: 0.8151 - val_loss: 0.7519 - val_mean_absolute_error: 0.7149
# Epoch 117/150
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0788 - mean_absolute_error: 0.8139 - val_loss: 0.7499 - val_mean_absolute_error: 0.7142
# Epoch 118/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0752 - mean_absolute_error: 0.8126 - val_loss: 0.7458 - val_mean_absolute_error: 0.7122
# Epoch 119/150
# 3/3 [==============================] - 0s 56ms/step - loss: 1.0710 - mean_absolute_error: 0.8109 - val_loss: 0.7412 - val_mean_absolute_error: 0.7102
# Epoch 120/150
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0669 - mean_absolute_error: 0.8089 - val_loss: 0.7364 - val_mean_absolute_error: 0.7073
# Epoch 121/150
# 3/3 [==============================] - 0s 75ms/step - loss: 1.0627 - mean_absolute_error: 0.8071 - val_loss: 0.7346 - val_mean_absolute_error: 0.7067
# Epoch 122/150
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0586 - mean_absolute_error: 0.8062 - val_loss: 0.7313 - val_mean_absolute_error: 0.7048
# Epoch 123/150
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0557 - mean_absolute_error: 0.8056 - val_loss: 0.7294 - val_mean_absolute_error: 0.7045
# Epoch 124/150
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0514 - mean_absolute_error: 0.8046 - val_loss: 0.7254 - val_mean_absolute_error: 0.7023
# Epoch 125/150
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0472 - mean_absolute_error: 0.8030 - val_loss: 0.7227 - val_mean_absolute_error: 0.7018
# Epoch 126/150
# 3/3 [==============================] - 0s 48ms/step - loss: 1.0435 - mean_absolute_error: 0.8024 - val_loss: 0.7211 - val_mean_absolute_error: 0.7016
# Epoch 127/150
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0393 - mean_absolute_error: 0.8014 - val_loss: 0.7191 - val_mean_absolute_error: 0.7009
# Epoch 128/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0364 - mean_absolute_error: 0.8010 - val_loss: 0.7160 - val_mean_absolute_error: 0.6994
# Epoch 129/150
# 3/3 [==============================] - 0s 46ms/step - loss: 1.0323 - mean_absolute_error: 0.7992 - val_loss: 0.7118 - val_mean_absolute_error: 0.6969
# Epoch 130/150
# 3/3 [==============================] - 0s 56ms/step - loss: 1.0288 - mean_absolute_error: 0.7982 - val_loss: 0.7100 - val_mean_absolute_error: 0.6953
# Epoch 131/150
# 3/3 [==============================] - 0s 39ms/step - loss: 1.0255 - mean_absolute_error: 0.7967 - val_loss: 0.7040 - val_mean_absolute_error: 0.6911
# Epoch 132/150
# 3/3 [==============================] - 0s 52ms/step - loss: 1.0205 - mean_absolute_error: 0.7943 - val_loss: 0.7025 - val_mean_absolute_error: 0.6899
# Epoch 133/150
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0175 - mean_absolute_error: 0.7934 - val_loss: 0.7016 - val_mean_absolute_error: 0.6893
# Epoch 134/150
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0136 - mean_absolute_error: 0.7923 - val_loss: 0.6994 - val_mean_absolute_error: 0.6881
# Epoch 135/150
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0103 - mean_absolute_error: 0.7911 - val_loss: 0.6963 - val_mean_absolute_error: 0.6866
# Epoch 136/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0067 - mean_absolute_error: 0.7897 - val_loss: 0.6941 - val_mean_absolute_error: 0.6855
# Epoch 137/150
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0034 - mean_absolute_error: 0.7891 - val_loss: 0.6927 - val_mean_absolute_error: 0.6845
# Epoch 138/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.9998 - mean_absolute_error: 0.7877 - val_loss: 0.6897 - val_mean_absolute_error: 0.6827
# Epoch 139/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.9967 - mean_absolute_error: 0.7870 - val_loss: 0.6888 - val_mean_absolute_error: 0.6822
# Epoch 140/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.9930 - mean_absolute_error: 0.7859 - val_loss: 0.6853 - val_mean_absolute_error: 0.6799
# Epoch 141/150
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9899 - mean_absolute_error: 0.7841 - val_loss: 0.6828 - val_mean_absolute_error: 0.6785
# Epoch 142/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9866 - mean_absolute_error: 0.7831 - val_loss: 0.6817 - val_mean_absolute_error: 0.6777
# Epoch 143/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9842 - mean_absolute_error: 0.7826 - val_loss: 0.6807 - val_mean_absolute_error: 0.6772
# Epoch 144/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9805 - mean_absolute_error: 0.7819 - val_loss: 0.6793 - val_mean_absolute_error: 0.6767
# Epoch 145/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.9771 - mean_absolute_error: 0.7808 - val_loss: 0.6761 - val_mean_absolute_error: 0.6750
# Epoch 146/150
# 3/3 [==============================] - 0s 131ms/step - loss: 0.9738 - mean_absolute_error: 0.7792 - val_loss: 0.6696 - val_mean_absolute_error: 0.6716
# Epoch 147/150
# 3/3 [==============================] - 0s 62ms/step - loss: 0.9707 - mean_absolute_error: 0.7766 - val_loss: 0.6651 - val_mean_absolute_error: 0.6692
# Epoch 148/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9682 - mean_absolute_error: 0.7759 - val_loss: 0.6637 - val_mean_absolute_error: 0.6686
# Epoch 149/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9648 - mean_absolute_error: 0.7746 - val_loss: 0.6611 - val_mean_absolute_error: 0.6673
# Epoch 150/150
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9614 - mean_absolute_error: 0.7741 - val_loss: 0.6624 - val_mean_absolute_error: 0.6678
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0222 - mean_absolute_error: 0.7743
# Mean Absolute Error on Test Data: 0.7743173241615295
# 4/4 [==============================] - 0s 4ms/step

# %% [markdown]
# MODELO CON TORCH

# %%
# Cargar datos (por ejemplo, desde un archivo CSV)
# Suponiendo que tienes un DataFrame llamado 'data' con columnas 'userId', 'movieId' y 'rating'
# ...

# Preprocesamiento de datos
num_movies = data['movieId'].nunique()

# Define el tamaño máximo del índice + 1 (porque los índices comienzan desde 0)
input_dim = max(max(data['userId']), max(data['movieId'])) + 1
num_movies = input_dim

# Crear embeddings para usuarios y películas
user_embedding = nn.Embedding(input_dim, 50)
movie_embedding = nn.Embedding(input_dim, 50)

# Crear conjuntos de entrenamiento y prueba
train, test = train_test_split(data, test_size=0.2, random_state=42)

# Preparar datos para DataLoader
train_users = torch.LongTensor(train['userId'].values)
train_movies = torch.LongTensor(train['movieId'].values)
train_ratings = torch.FloatTensor(train['rating'].values)

test_users = torch.LongTensor(test['userId'].values)
test_movies = torch.LongTensor(test['movieId'].values)
test_ratings = torch.FloatTensor(test['rating'].values)

train_dataset = TensorDataset(train_users, train_movies, train_ratings)
test_dataset = TensorDataset(test_users, test_movies, test_ratings)

# Crear DataLoader
batch_size = 512
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# Definir el modelo de recomendación
class Recommender(nn.Module):
    def __init__(self, num_usr, num_movs, embedding_size=50, hidden_size=128):
        super(Recommender, self).__init__()
        self.user_embedding = nn.Embedding(num_usr, embedding_size)
        self.movie_embedding = nn.Embedding(num_movs, embedding_size)
        self.fc1 = nn.Linear(embedding_size * 2, hidden_size)
        self.fc2 = nn.Linear(hidden_size, 1)

    def forward(self, user, movie):
        user_embed = self.user_embedding(user)
        movie_embed = self.movie_embedding(movie)
        x = torch.cat([user_embed, movie_embed], dim=1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Instanciar el modelo, la función de pérdida y el optimizador
model = Recommender(input_dim, num_movies)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Entrenar el modelo
num_epochs = 100

print_interval = int(num_epochs / 10) 

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    for user, movie, rating in train_loader:
        optimizer.zero_grad()
        output = model(user, movie).view(-1)
        loss = criterion(output, rating)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * user.size(0)
    train_loss /= len(train_loader.dataset)
    # Imprimir progreso cada 10% de las épocas
    if (epoch + 1) % print_interval == 0 or epoch == num_epochs - 1:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}')
    # print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}')

# Evaluar el modelo en el conjunto de prueba
model.eval()
test_loss = 0.0
with torch.no_grad():
    for user, movie, rating in test_loader:
        output = model(user, movie).view(-1)
        print(f'REAL RATINFG: {rating} ------------ PREDICT RATING {output}')
        loss = criterion(output, rating)
        test_loss += loss.item() * user.size(0)
test_loss /= len(test_loader.dataset)
print(f'Test Loss: {test_loss:.4f}')

# %%
# # Cargar datos (por ejemplo, desde un archivo CSV)
# # Suponiendo que tienes un DataFrame llamado 'data' con columnas 'userId', 'movieId' y 'rating'
# # ...

# # Preprocesamiento de datos
# # Define el tamaño máximo del índice + 1 (porque los índices comienzan desde 0)
# input_dim = max(max(data['userId']), max(data['movieId'])) + 1

# # Define el tamaño de la capa de embeddings (puedes ajustar este valor según sea necesario)
# embedding_size = 50

# # Crear conjuntos de entrenamiento y prueba
# train, test = train_test_split(data, test_size=0.2, random_state=42)

# # Definir la arquitectura del modelo de recomendación
# user_input = Input(shape=(1,))
# movie_input = Input(shape=(1,))

# user_embedding = Embedding(input_dim=input_dim, output_dim=embedding_size)(user_input)
# movie_embedding = Embedding(input_dim=input_dim, output_dim=embedding_size)(movie_input)

# user_flat = Flatten()(user_embedding)
# movie_flat = Flatten()(movie_embedding)

# concatenated = Concatenate()([user_flat, movie_flat])

# dense_1 = Dense(128, activation='relu')(concatenated)
# output = Dense(1)(dense_1)

# # Crear el modelo
# model = Model(inputs=[user_input, movie_input], outputs=output)

# # Compilar el modelo
# model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.01))

# # Entrenar el modelo
# model.fit([train['userId'], train['movieId']], train['rating'], batch_size=512, epochs=100, validation_split=0.2, verbose=0)

# # Evaluar el modelo en el conjunto de prueba
# loss = model.evaluate([test['userId'], test['movieId']], test['rating'])
# print(f'Loss en el conjunto de prueba: {loss}')
