# %%
# %matplotlib inline

from math import pi
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, clear_output

# Generar datos aleatorios
x = np.linspace(1, 1000, 5000)
y = np.random.randint(1, 1000, 5000)

# Crear subplot y figura
fig, ax = plt.subplots()
line1, = ax.plot(x, y)

# Configurar etiquetas
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Updating plot...")

# Bucle de actualización
for _ in range(50):
    # Actualizar los valores de x e y
    line1.set_xdata(x * _)
    line1.set_ydata(y)

    # Volver a dibujar toda la figura
    fig.canvas.draw()
    
    # Limpiar la salida y mostrar la figura
    clear_output(wait=True)
    display(fig)

    # Esperar y permitir la actualización del GUI
    plt.pause(0.05)
    
# La siguiente línea es opcional y permite cerrar la figura después de la animación
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 32
#      30 # Limpiar la salida y mostrar la figura
#      31 clear_output(wait=True)
# ---> 32 display(fig)
#      34 # Esperar y permitir la actualización del GUI
#      35 plt.pause(0.05)
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\matplotlib\backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\matplotlib\figure.py:1744, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1741     artists = bbox_extra_artists
#    1743 for a in artists:
# -> 1744     bbox = a.get_tightbbox(renderer)
#    1745     if bbox is not None:
#    1746         bb.append(bbox)
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:4394, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4392 for title in [self.title, self._left_title, self._right_title]:
#    4393     if title.get_visible():
# -> 4394         bt = title.get_window_extent(renderer)
#    4395         if for_layout_only and bt.width > 0:
#    4396             # make the title bbox 1 pixel wide so its width
#    4397             # is not accounted for in bbox calculations in
#    4398             # tight/constrained_layout
#    4399             bt.x0 = (bt.x0 + bt.x1) / 2 - 0.5
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\matplotlib\text.py:961, in Text.get_window_extent(self, renderer, dpi)
#     959 bbox, info, descent = self._get_layout(self._renderer)
#     960 x, y = self.get_unitless_position()
# --> 961 x, y = self.get_transform().transform((x, y))
#     962 bbox = bbox.translated(x, y)
#     963 return bbox
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\matplotlib\transforms.py:2415, in CompositeGenericTransform.transform_affine(self, points)
#    2413 def transform_affine(self, points):
#    2414     # docstring inherited
# -> 2415     return self.get_affine().transform(points)
#
# File c:\Users\jaime\Anaconda3\lib\site-packages\matplotlib\transforms.py:2441, in CompositeGenericTransform.get_affine(self)
#    2439     return self._b.get_affine()
#    2440 else:
# -> 2441     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2442                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:

# %%
import matplotlib
matplotlib.use('TkAgg')  # 'TkAgg' es el backend de Tkinter

from math import pi
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, clear_output

# Generar datos aleatorios
x = np.linspace(1, 1000, 5000)
y = np.random.randint(1, 1000, 5000)

# Crear subplot y figura
fig, ax = plt.subplots()
line1, = ax.plot(x, y)

# Configurar etiquetas
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Updating plot...")

# Bucle de actualización
for _ in range(50):
    # Actualizar los valores de x e y
    line1.set_xdata(x * _)
    line1.set_ydata(y)

    # Volver a dibujar toda la figura
    fig.canvas.draw()
    
    # Limpiar la salida y mostrar la figura
    clear_output(wait=True)
    plt.pause(0.05)

# La siguiente línea es opcional y permite cerrar la figura después de la animación
plt.close(fig)
